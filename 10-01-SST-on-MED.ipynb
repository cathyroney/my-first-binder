# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # COPERNICUS MARINE MEDITERRANEAN SEA SURFACE TEMPERATURE TRAINING
#
# <div style="text-align: right"><i> 10-01-SST-on-MED </i></div>
#
# ***
# <center><h1>How to visualize maps and time series of Sea Surface Temperature (SST)</h1></center>

# %% [markdown]
# ***
# **General Note 1**: This Notebook has been updated on Feb 22 and is not exactly similar to the one in the tutorial video. No worries, the aim of this Notebook is still the same as well as the results.
#
# **General Note 2**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 3**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>

# %% [markdown]
# ***
# # Table of contents
# - [1. Introduction](#1.-Introduction)
# - [2. About the data](#2.-About-the-data)
#     - [2.1. First example](#2.1.-First-example)
#         - [2.1.1. Product description](#2.1.1.-Product-description)
#         - [2.1.2. Get more info on the product](#2.1.2.-Get-more-info-on-the-product)
#         - [2.1.3. Parameters used for downloading data](#2.1.3.-Parameters-used-for-downloading-data)
#     - [2.2. Second example](#2.2.-Second-example)
#         - [2.2.1. Product description](#2.2.1.-Product-description)
#         - [2.2.2. Get more info on the product](#2.2.2.-Get-more-info-on-the-product)
#         - [2.2.3. Parameters used for downloading data (two datasets)](#2.2.3.-Parameters-used-for-downloading-data-(two-datasets))
#     - [2.3. Download data with motuclient](#2.3.-Download-data-with-motuclient)
#         - [2.3.1. Download motuclient](#2.3.1.-Download-motuclient)
#         - [2.3.2. First example](#2.3.2.-First-example)
#         - [2.3.3. Second example](#2.3.3.-Second-example)
# - [3. Exercise n.1: Plot of maps](#3.-Exercise-n.1:-Plot-of-maps)
#     - [3.1. Required modules](#3.1.-Required-modules)
#     - [3.2. Import the modules](#3.2.-Import-the-modules)
#     - [3.3. Access the data](#3.3.-Access-the-data)
#     - [3.4. Set the configuration](#3.4.-Set-the-configuration)
#     - [3.5. Plot the variables](#3.5.-Plot-the-variables)
# - [4. Exercise n.2: Plot of time series](#4.-Exercise-n.2:-Plot-of-Time-series)
#     - [4.1. Required modules](#4.1.-Required-modules)
#     - [4.2. Import the modules](#4.2.-Import-the-modules)
#     - [4.3. Access the data](#4.3.-Access-the-data)
#     - [4.4. Set the configuration](#4.4.-Set-the-configuration)
#     - [4.5. Plot the time series](#4.5.-Plot-the-time-series)
# - [5. Conclusion](#5.-Conclusion)
# ***

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# This python notebook contains two examples of visualization of the Sea Surface Temperature (SST) products for the Mediterranean sea.
#
# The first example will show how to plot a map of Sea Surface Temperature data using the Near Real Time daily multisensor merged (supercollated) SST field at Ultra High Resolution.
# The second example will show how to make a plot of values of Sea Surface Temperature in two different locations (and of their monthly average) as obtained from interpolated Near Real Time daily time series.

# %% [markdown]
# # 2. About the data
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# Remotely-sensed level 3 (L3) and level 4 (L4) Sea Surface Temperature (SST) datasets covering the Mediterranean Sea are operationally produced and distributed both as near-real time and reprocessed products by the Consiglio Nazionale delle Ricerche-Istituto di Scienze Marine-Gruppo di Oceanografia da Satellite (CNR-ISMAR-GOS).

# %% [markdown]
# ## 2.1. First example

# %% [markdown]
# ### 2.1.1. Product description
#
# ### The first example is based on the product: [SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012](https://resources.marine.copernicus.eu/product-detail/SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012/INFORMATION)

# %% [markdown]
# SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012 data consist of level 3 supercollated (L3S) merged-multisensor SST data remapped over the Mediterranean Sea at high (1/16°) and Ultra High (0.01°) spatial resolution, representative of night SST values (00:00 UTC). The L3S data are produced selecting only the highest quality input data within a strict temporal window (local nightime), to avoid diurnal cycle and cloud contamination. Different L3 images from different sensors and/or satellite passes (if present) are merged into a single daily super-collated image (L3S).
#
# The SST estimated from one sensor might significantly differ from that retrieved by another, mainly because of the differences among the sensors (number of bands, spectral resolution, scanning/viewing geometry, etc.) and/or of the different algorithms applied, which, in particular, might correct very differently the atmospheric contribution to the measured brightness temperature. Consequently, a hierarchical iterative bias adjustment procedure (using a ranking based on each sensor accuracy) is applied to L3P data before super-collating. For each pixel, only the value from the "best" sensor is kept. Uncorrected values from selected sensors are provided (for each pixel) in variable "sea_surface_tenperature", while corrected values are provided in "adjusted_sea_surface_temperature" variable.
#
# The L3S processing is run daily, but L3S files are produced only if valid SST measurements are present on the area considered. The most recent CNR MED L3S products are directly accessible to CMEMS users. At present, data older than 2 years can be accessed by specific request via CMEMS Service Desk servicedesk.cmems@mercator-ocean.eu.
#
# Reference: <i>Buongiorno Nardelli B., C.Tronconi, A. Pisano, R.Santoleri, 2013: High and Ultra-High resolution processing of satellite Sea Surface Temperature data over Southern European Seas in the framework of MyOcean project, Rem. Sens. Env., 129, 1-16, [doi:10.1016/j.rse.2012.10.012.](https://www.sciencedirect.com/science/article/abs/pii/S003442571200394X?via%3Dihub)</i>
#
# <img src="./img/SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012.png">

# %% [markdown]
# ### 2.1.2. Get more info on the product
#
# 1. You can find info on this product and access to the download services in the [dedicated Product Page on Copernicus Marine (CMEMS) Web portal](https://resources.marine.copernicus.eu/product-detail/SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012/INFORMATION)
# <br>
# 2. For **detailed information** about the product, please consult the **document**: [Product User Manual (PUM)](https://catalogue.marine.copernicus.eu/documents/PUM/CMEMS-SST-PUM-010-004-006-012-013.pdf)
# <br>
# 3. For information about **the quality and validation** of the product, please consult the **document**: [Quality Information Document (QUID)](https://catalogue.marine.copernicus.eu/documents/QUID/CMEMS-SST-QUID-010-004-006-012-013.pdf)

# %% [markdown]
# ### 2.1.3. Parameters used for downloading data
#
# | Parameter | Value |
# | :--- | :---|
# | **Product** | SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012 |
# | **Datasets** | SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012_b |
# | **Frequency** | daily |
# | **Lat min** | 30.0 |
# | **Lat max** | 46.0  |
# | **Lon min** | -18.0 |
# | **Lon max** | 36.0 |
# | **Timesteps** | from  2020-06-15T00:00 to 2020-06-15T00:00 |
# | **Variables** | sea_surface_temperature, adjusted_sea_surface_temperature |
# | **Service for downloading** | SUBSETTER |
#
# ***

# %% [markdown]
# ## 2.2. Second example

# %% [markdown]
# ### 2.2.1. Product description
# ### The second example is based on the product:[SST_MED_SST_L4_NRT_OBSERVATIONS_010_004](https://resources.marine.copernicus.eu/product-detail/SST_MED_SST_L4_NRT_OBSERVATIONS_010_004/INFORMATION)

# %% [markdown]
# SST_MED_SST_L4_NRT_OBSERVATIONS_010_004 product provides daily gap-free Sea Surface Temperature maps (L4) at high (HR 0.0625°) and ultra high (UHR 0.01°) spatial resolution over the Mediterranean Sea. These SST datasets are based on the night-time images collected by the infrared sensors mounted on different satellite platforms, and cover the Southern European Seas.
#
# The CNR-ISMAR-GOS processing chain includes several modules, from the data extraction and preliminary quality control, to cloudy pixel removal and satellite images collating/merging (see also 2.1). A two-step algorithm finally allows to fill in SST data gaps at high (HR 0.0625°) and ultra-high (UHR 0.01°) spatial resolution, applying a classical optimal interpolation (OI) algorithm.
#
# OI gives an estimate of an anomaly field with respect to a first guess, assuming the statistical characteristics of the variability are known (background error covariance and observation error covariance). The SST L4 analysis is then obtained as a linear combination of the observations, weighted directly with their correlation to the interpolation point and inversely with their cross-correlation and measurement error. The approach used to interpolate the SST at UHR is based on a simple concept of scales separation/decomposition. In practice,  the lower resolution (HR) L4 map, properly re-binned on the UHR grid (through a simple bilinear algorithm), is used as first guess for a second interpolation step, where the SST anomalies, estimated now at 1 km, only contain the small scale signals.
#
# Final L4 data are also used to estimate the SST anomaly with respect to a pentad climatology. The basic design and the main algorithms used are described in the following papers. The most recent CNR MED L4 products are directly accessible to CMEMS users. At present, data older than 2 years can be accessed by specific request via CMEMS Service Desk servicedesk.cmems@mercator-ocean.eu
#
# Reference: <i>Buongiorno Nardelli B., C.Tronconi, A. Pisano, R.Santoleri, 2013: High and Ultra-High resolution processing of satellite Sea Surface Temperature data over Southern European Seas in the framework of MyOcean project, Rem. Sens. Env., 129, 1-16, [doi:10.1016/j.rse.2012.10.012.](https://www.sciencedirect.com/science/article/abs/pii/S003442571200394X?via%3Dihub)</i>
#
# <img src="./img/SST_MED_SST_L4_NRT_OBSERVATIONS_010_004.png">

# %% [markdown]
# ### 2.2.2. Get more info on the product
#
# 1. You can find info on this product and access to the download services in the [dedicated Product Page on Copernicus Marine (CMEMS) Web portal](https://resources.marine.copernicus.eu/product-detail/SST_MED_SST_L4_NRT_OBSERVATIONS_010_004/INFORMATION)
# <br>
# 2. For **detailed information** about the product, please consult the **document**: [Product User Manual (PUM)](https://catalogue.marine.copernicus.eu/documents/PUM/CMEMS-SST-PUM-010-004-006-012-013.pdf)
# <br>
# 3. For information about **the quality and validation** of the product, please consult the **document**: [Quality Information Document (QUID)](https://catalogue.marine.copernicus.eu/documents/QUID/CMEMS-SST-QUID-010-004-006-012-013.pdf)

# %% [markdown]
# ### 2.2.3. Parameters used for downloading data (two datasets)
#
# | Parameter | Value |
# | :--- | :---|
# | **Product** | SST_MED_SST_L4_NRT_OBSERVATIONS_010_004 |
# | **Datasets** | SST_MED_SST_L4_NRT_OBSERVATIONS_010_004_c_V2 |
# | **Frequency** | daily |
# | **Lat min** | 35.0 and 40.0 |
# | **Lat max** | 35.1 and 40.1  |
# | **Lon min** | 18.0 and 12.0 |
# | **Lon max** | 18.1 and 12.1 |
# | **Timesteps** | both from  2018-06-01T00:00 to 2020-05-31T00:00 |
# | **Variables** | analysed_sst |
# | **Service for downloading** | SUBSETTER |
#
# ***

# %% [markdown]
# ## 2.3. Download data with motuclient

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Get the CMEMS User credentials</b>
# <hr>
# Before being able to run the following exercises on your PC and to download the needed data, please be sure to have your CMEMS User credentials. Otherwise please get them <a href="http://marine.copernicus.eu/services-portfolio/register-now/" target="_blank">here</a>.

# %% [markdown]
# ### 2.3.1. Download motuclient

# %% [markdown]
# Data can be alternatively downloaded with **motuclient**, a multiplatform python script to automate extraction of information from the Marine Copernicus portal. To install motuclient:

# %% [markdown]
# ```
# !pip install motuclient
# ```

# %% [markdown]
# To get more info on motuclient visit the related [web page](https://marine.copernicus.eu/faq/what-are-the-motu-and-python-requirements/#motu-client).

# %% [markdown]
# ### 2.3.2. First example

# %% [markdown]
# You'll be able to download data with the following command line that you have to copy to another cell for being execute (**NOTE:** don't forget to set username and password):

# %% [markdown]
# ```
# !python -m motuclient --motu http://nrt.cmems-du.eu/motu-web/Motu \
# --service-id SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012-TDS \
# --product-id SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012_b \
# --longitude-min -18.120832443237305 --longitude-max 36.24583435058594 \
# --latitude-min 30.254167556762695 --latitude-max 45.99583435058594 \
# --date-min "2020-06-15 00:00:00" --date-max "2020-06-15 00:00:00" \
# --variable adjusted_sea_surface_temperature --variable quality_level \
# --variable sea_surface_temperature --variable source_of_sst --out-dir ./data \
# --out-name 10-01-A.nc --user <USERNAME> --pwd <PASSWORD>
# ```

# %% [markdown]
# Insert the download command below, if needed:

# %% [markdown]
# To check if the file has been correctly downloaded:

# %%
import os
for filename in os.listdir("data"):
    print(filename)
# Out:
# 10-01-SST-on-MED.ipynb
# 10-01-A.nc
# 10-01-C.nc
# 10-01-B.nc

# %% [markdown]
# ### 2.3.3. Second example

# %% [markdown]
# You'll be able to download data with the following command lines that you have to copy to another cell for being execute (**NOTE:** don't forget to set username and password):

# %% [markdown]
# ```
# !python -m motuclient --motu http://nrt.cmems-du.eu/motu-web/Motu \
#     --service-id SST_MED_SST_L4_NRT_OBSERVATIONS_010_004-TDS \
#     --product-id SST_MED_SST_L4_NRT_OBSERVATIONS_010_004_c_V2 \
#     --longitude-min 12.0 --longitude-max 12.1 \
#     --latitude-min 40.0 --latitude-max 40.1 \
#     --date-min "2018-06-01 00:00:00" --date-max "2020-05-31 00:00:00" \
#     --variable analysed_sst \
#     --out-dir ./data --out-name "10-01-B.nc" --user <USERNAME> --pwd <PASSWORD>
# ```

# %% [markdown]
# Insert the download command below, if needed:

# %% [markdown]
# ```
# !python -m motuclient --motu http://nrt.cmems-du.eu/motu-web/Motu \
#     --service-id SST_MED_SST_L4_NRT_OBSERVATIONS_010_004-TDS \
#     --product-id SST_MED_SST_L4_NRT_OBSERVATIONS_010_004_c_V2 \
#     --longitude-min 18.0 --longitude-max 18.1 \
#     --latitude-min 35.0 --latitude-max 35.1 \
#     --date-min "2018-06-01 00:00:00" --date-max "2020-05-31 00:00:00" \
#     --variable analysed_sst \
#     --out-dir ./data --out-name "10-01-C.nc" --user <USERNAME> --pwd <PASSWORD>
# ```

# %% [markdown]
# Insert the download command below, if needed:

# %% [markdown]
# To check if the file has been correctly downloaded:

# %%
import os
for filename in os.listdir("data"):
    print(filename)
# Out:
# 10-01-SST-on-MED.ipynb
# 10-01-A.nc
# 10-01-C.nc
# 10-01-B.nc

# %% [markdown]
# # 3. Exercise n.1: Plot of maps

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# In this exercise we will see how to plot maps of SST in the Mediterranean Sea.

# %% [markdown]
# ### Requirement: Python version 3.7
# Check your python version with:

# %%
# !python --version
# Out:
# Python 3.13.11

# %% [markdown]
# If needed, you can install the right Python version in this way:
# ```
# conda install python=3.7
# ```

# %% [markdown]
# ## 3.1. Required modules

# %% [markdown]
# | Module name | Description |
# | :--- | :---|
# | **os** | [ Miscellaneous operating system interfaces](https://docs.python.org/3.7/library/os.html) for managing paths, creating directories,... |
# | **numpy** | [NumPy](https://numpy.org/) is the fundamental package for scientific computing with Python and for managing ND-arrays |
# | **xarray** | [Xarray](http://xarray.pydata.org/en/stable/) introduces labels in the form of dimensions, coordinates and attributes on top of raw NumPy-like arrays, which allows for a more intuitive, more concise, and less error-prone developer experience. |
# | **matplotlib** |[Matplotlib](https://matplotlib.org/) is a Python 2D plotting library which produces publication quality figures |
# | **cartopy** |[Cartopy](https://scitools.org.uk/cartopy/docs/latest/index.html/) is a library for plotting maps and geospatial data analyses in Python |
# | **datetime** |[The datetime module](https://docs.python.org/3.8/library/datetime.html) supplies classes for manipulating dates and times in both simple and complex ways. |
# | **pandas** |[pandas](https://pandas.pydata.org/) is a library providing high-performance, easy-to-use data structures and data analysis tools for Python |

# %% [markdown]
# ### Code cells allow you to enter and run Python code
# Run a code cell using <code>Shift-Enter</code> or pressing the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button in the toolbar above:

# %% [markdown]
# ### Install the needed Python modules (for local installation, can be skipped during Training)

# %% [markdown]
# If you are using the standard *Anaconda* installation, you can install the modules executing the following command in a new cell:

# %% [markdown]
# ```
# conda install numpy xarray matplotlib cartopy netcdf4 proj4 basemap-data-hires cftime
# ```

# %% [markdown]
# Then, as requested, please restart the kernel.
#
# The kernel maintains the state of a notebook's computations. You can reset this state by restarting the kernel. This is done by clicking on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> in the toolbar above.

# %% [markdown]
# ## 3.2. Import the modules

# %% [markdown]
# Before going on, since we are in Jupyter Notebook, we need to set the environment in order to properly load some of the required libraries.

# %%
import os

# %% [markdown]
# In case you get an error in the following steps, try setting the variable os.environ'PROJ_LIB to the shared path of your conda environment. For example by executing in a python cell (don't forget to replace <PATH_TO_ANACONDA> with the proper values):
#
# os.environ'PROJ_LIB' = "<PATH_TO_ANACONDA>/share/proj"

# %% [markdown]
# To avoid the warning messages during the execution and installation process, at first remove them:

# %%
import warnings
warnings.filterwarnings('ignore')
#os.environ['PROJ_LIB'] = "<PATH_TO_ANACONDA>/share/proj"  #uncomment this replacing <PATH_TO_ANACONDA> with proper value

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import datetime
import pandas
from matplotlib.colors import LogNorm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 import numpy as np
# ----> 2 import xarray as xr
#       3 import matplotlib.pyplot as plt
#       4 import cartopy.crs as ccrs
#       5 import cartopy.feature as cfeature
#
# ModuleNotFoundError: No module named 'xarray'

# %% [markdown]
# *Don't change the following constants, which define the training and the notebook codes*:

# %%
REGION_CODE = "10"
NB_CODE = "01"

# %% [markdown]
# **checkDir**: function for creating a path, if needed

# %%
def checkDir(outPath):
    if not os.path.exists(outPath):
        os.makedirs(outPath)

# %% [markdown]
# **getRangeIndexes**: function for getting the indexes of the array *arr* between the *var_min* and *var_max* values:

# %%
def getRangeIndexes(arr, var_min, var_max):
    return np.where((arr >= var_min) & (arr <= var_max))[0]

# %% [markdown]
# Set the paths:

# %%
# Path for netcdf files
data_path = './data'
# Path for the output files (images, etc)
out_path = './out/'+REGION_CODE+'-'+NB_CODE

# %% [markdown]
# Check the current directories:

# %%
for filename in os.listdir():
    print(filename)
# Out:
# .DS_Store
# .ipynb_checkpoints
# 10-01-SST-on-MED - Copie.ipynb
# 10-01-SST-on-MED.ipynb
# data
# img
# out

# %%
# Create directories
checkDir(data_path)
checkDir(out_path)

# %% [markdown]
# Check if the new directories have been created and if the data files are available:

# %%
for path in [data_path, out_path]:
    if os.path.isdir(path):
        print(path)
# Out:
# ./data
# ./out/10-01

# %%
for filename in os.listdir(data_path):
    print(filename)
# Out:
# 10-01-A.nc
# 10-01-B.nc
# 10-01-C.nc
# 10-01-SST-on-MED.ipynb

# %% [markdown]
# ## 3.3. Access the data

# %%
# Input netcdf file
sst_f = "10-01-A.nc"
 
# Build the complete nc path
sst_nc = os.path.join(data_path, sst_f)

# %%
# Open the nc dataset
sst_ds = xr.open_dataset(sst_nc,use_cftime='gregorian')

# %% [markdown]
# ### Get info about the dataset:

# %%
sst_ds.info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:                           (time: 1, lat: 1890, lon: 6525)
# Coordinates:
#   * time                              (time) object 2020-06-15 00:00:00
#   * lat                               (lat) float32 30.25 30.26 ... 45.99 46.0
#   * lon                               (lon) float32 -18.12 -18.11 ... 36.25
# Data variables:
#     adjusted_sea_surface_temperature  (time, lat, lon) float32 ...
#     quality_level                     (time, lat, lon) float32 ...
#     sea_surface_temperature           (time, lat, lon) float32 ...
#     source_of_sst                     (time, lat, lon) float32 ...
# Attributes: (12/58)
#     Conventions:                CF-1.4
#     title:                      Mediterranean SST, L3S, 1km daily (SST_MED_SS...
#     summary:                    The MED CNR Sea Surface Temperature L3S produ...
#     references:                 Buongiorno Nardelli, B., C. Tronconi, a. Pisa...
# ...

# %% [markdown]
# And about the variables:

# %%
sst_ds.data_vars
# Out:
# Data variables:
#     adjusted_sea_surface_temperature  (time, lat, lon) float32 ...
#     quality_level                     (time, lat, lon) float32 ...
#     sea_surface_temperature           (time, lat, lon) float32 ...
#     source_of_sst                     (time, lat, lon) float32 ...

# %% [markdown]
# ... the coordinates:

# %%
sst_ds.coords
# Out:
# Coordinates:
#   * time     (time) object 2020-06-15 00:00:00
#   * lat      (lat) float32 30.25 30.26 30.27 30.28 ... 45.97 45.98 45.99 46.0
#   * lon      (lon) float32 -18.12 -18.11 -18.1 -18.1 ... 36.22 36.23 36.24 36.25

# %% [markdown]
# ## 3.4. Set the configuration

# %%
# Set the coordinate names (used later for accessing the data)
lon_name = "lon"
lat_name = "lat"
time_name = "time"

# %%
# Set the variable names
var_name = "adjusted_sea_surface_temperature" #  multi-sensor bias-adjusted sea surface temperature
#var_name = "sea_surface_temperature" #  multi-sensor sea surface temperature before sensor bias adjustment

# %% [markdown]
# <i>You can play with the choice of the variable to plot to see the effect of the sensor bias adjustment on the final merged SST field</i>

# %% [markdown]
# ## 3.5. Plot the variables

# %% [markdown]
# ### Configure the variables for the plots

# %%
# Data to plot
var_sel = sst_ds[var_name]

# --- Set up the arrays of coordinates for the selected dataset ---
# 
lats = var_sel[lat_name]
lons = var_sel[lon_name]
times = var_sel[time_name]
    
# --- Set the area: choose the min and max values for the coordinates ---
# (and comment with the symbol # the unnecessary ones!):                                                               
                                                                 
# # Set lat-lon limits - CUSTOM:  focus on Sicily Channel
#lon_min = 10
#lon_max = 18
#lat_min = 32
#lat_max = 38

# Set lat-lon limits - FULL AREA
lat_min = lats.min()
lat_max = lats.max()
lon_min = lons.min()
lon_max = lons.max()

# set start and end date
start_date = times.min()
end_date = times.max()

# Set the variable min and max values for the plot and the colorbar (otherwise assign None):
# min_value, max_value = None, None
min_value, max_value = 290,300

# -- Set the time period --- 
plot_date = np.datetime64(datetime.datetime(2020,6,15,0))

# %%
# Plot configuration
width_inch = 16
height_inch = 8

# Colorbar configuration
cmap = "Spectral_r"
cbar_position = "right"

title_fontstyle = {
    "fontsize": "14",
    "fontstyle": "italic",
    "fontweight": "bold",
    "pad": 30
}

label_fontstyle = {
    "fontsize": "12",
    "labelpad": 30
}

# Set the coordinates indexes
lat_indexes = getRangeIndexes(lats, lat_min, lat_max)
lon_indexes = getRangeIndexes(lons, lon_min, lon_max)
time_indexes = getRangeIndexes(times, start_date, end_date)

# Get the selected coordinates:
lats_sel = lats[lat_indexes]
lons_sel = lons[lon_indexes]

# Get the timestep
timestep = np.datetime_as_string(plot_date,'h')

# Get the data
data = var_sel[time_indexes[0], lat_indexes, lon_indexes]

# Initialise the figure
f=plt.figure(figsize=(width_inch, height_inch))

## imshow the data
min_value = data.min() if min_value is None else min_value
max_value = data.max() if max_value is None else max_value

ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)
gl.right_labels = False
gl.top_labels = False
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')
ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.LAKES,facecolor='white',edgecolor='k')
ax.set_extent([lon_min,lon_max, lat_min, lat_max],crs=ccrs.PlateCarree())

#display the dataset
im = ax.pcolor(lons_sel, lats_sel, data, vmin=min_value, vmax=max_value, cmap=cmap)
    
## draw colorbar
f.colorbar(im,ax=ax,fraction=0.03,pad=0.04)

# set title
title_sel = data.long_name
var_str = "{} [{}]".format(title_sel, data.units)
title = ' - '.join((var_str, timestep))
    
## draw title
ax.set_title(title, **title_fontstyle)
    
# output file
output_file = os.path.join(out_path,title.translate(str.maketrans(' ,','__'))) + ".png"

# save the output file
plt.savefig(output_file)
plt.show()
plt.close()

# %% [markdown]
# If you can't see easily the maps, you can disable the scrolling.
# Choose the previous cell (the one with the maps), then select in the menu: **Cell &rarr; Current Output &rarr; Toggle Scrolling**

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### LET'S TRY: Change the plot!
#
# If you want, you can change the above plot.
#
# For example, you could:
# - change the area (remember to change the *skip_points* too!)
# - change the min/max values for the chosen variable
# - change the variable to verify impact of sensor bias adjustment before merging

# %% [markdown]
# ***

# %% [markdown]
# # 4. Exercise n.2: Plot of Time series
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# In this exercise we will see how to plot the time series of sea surface temperature for two small regions in the Mediterranean Sea.
# The first region is located in the central Tyrrhenian Sea, the second in the central Ionian Sea).

# %% [markdown]
# ### Requirement: Python version 3.7
# Check your python version with:

# %%
# !python --version

# %% [markdown]
# If needed, you can install the right Python version in this way:
# ```
# conda install python=3.7
# ```

# %% [markdown]
# ## 4.1. Required modules

# %% [markdown]
# The list of modules required to run this exercise is reported in the table below:

# %% [markdown]
# | Module name | Description |
# | :--- | :---|
# | **os** | [ Miscellaneous operating system interfaces](https://docs.python.org/3.7/library/os.html) for managing paths, creating directories,... |
# | **numpy** | [NumPy](https://numpy.org/) is the fundamental package for scientific computing with Python and for managing ND-arrays |
# | **xarray** | [Xarray](http://xarray.pydata.org/en/stable/) introduces labels in the form of dimensions, coordinates and attributes on top of raw NumPy-like arrays, which allows for a more intuitive, more concise, and less error-prone developer experience. |
# | **matplotlib** |[Matplotlib](https://matplotlib.org/) is a Python 2D plotting library which produces publication quality figures |
# | **datetime** |[The datetime module](https://docs.python.org/3.8/library/datetime.html) supplies classes for manipulating dates and times in both simple and complex ways. |
# | **pandas** |[pandas](https://pandas.pydata.org/) is a library providing high-performance, easy-to-use data structures and data analysis tools for Python |

# %% [markdown]
# ### Code cells allow you to enter and run Python code
# Run a code cell using <code>Shift-Enter</code> or pressing the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button in the toolbar above:

# %% [markdown]
# ### Install the needed Python modules (for local installation, can be skipped during Training)

# %% [markdown]
# If you are using the standard *Anaconda* installation, you can install the modules executing the following command in a new cell:

# %% [markdown]
# ```
# conda install numpy xarray matplotlib netcdf4  cftime
# ```

# %% [markdown]
# Then, as requested, please restart the kernel.
#
# The kernel maintains the state of a notebook's computations. You can reset this state by restarting the kernel. This is done by clicking on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> in the toolbar above.

# %% [markdown]
# ## 4.2. Import the modules

# %% [markdown]
# Before going on, since we are in Jupyter Notebook, we need to set the environment in order to properly load some of the required libraries.

# %%
import os

# %% [markdown]
# In case you get an error in the following steps, try setting the variable os.environ'PROJ_LIB to the shared path of your conda environment. For example by executing in a python cell (don't forget to replace <PATH_TO_ANACONDA> with the proper values):
#
# os.environ'PROJ_LIB' = "<PATH_TO_ANACONDA>/share/proj"

# %% [markdown]
# To avoid the warning messages during the execution and installation process, at first remove them:

# %%
import warnings
warnings.filterwarnings('ignore')
#os.environ['PROJ_LIB'] = "<PATH_TO_ANACONDA>/share/proj"  #uncomment this replacing <PATH_TO_ANACONDA> with proper value if needed

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import matplotlib.dates as mdates

# %% [markdown]
# *Don't change the following constants, which define the training and the notebook codes*:

# %%
REGION_CODE = "10"
NB_CODE = "01"

# %% [markdown]
# **checkDir**: function for creating a path, if needed

# %%
def checkDir(outPath):
    if not os.path.exists(outPath):
        os.makedirs(outPath)

# %% [markdown]
# **getRangeIndexes**: function for getting the indexes of the array *arr* between the *var_min* and *var_max* values:

# %%
def getRangeIndexes(arr, var_min, var_max):
    return np.where((arr >= var_min) & (arr <= var_max))[0]

# %% [markdown]
# Set the paths:

# %%
# Path for netcdf files
data_path = './data'

# Path for the output files (images, etc)
out_path = './out/'+REGION_CODE+'-'+NB_CODE

# %% [markdown]
# ## 4.3. Access the data

# %%
# Input netcdf file
sst_f1 = "10-01-B.nc"
sst_f2 = "10-01-C.nc"
 
# Build the complete nc path
sst_nc1 = os.path.join(data_path, sst_f1)
sst_nc2 = os.path.join(data_path, sst_f2)

# %%
# Open the nc datasets
sst_ds1 = xr.open_dataset(sst_nc1)
sst_ds2 = xr.open_dataset(sst_nc2)

# %% [markdown]
# ### Get info about the datasets:

# %%
sst_ds1.info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:       (time: 731, lat: 13, lon: 13)
# Coordinates:
#   * time          (time) datetime64[ns] 2018-06-01 2018-06-02 ... 2020-05-31
#   * lat           (lat) float32 40.0 40.0 40.01 40.02 ... 40.07 40.08 40.09 40.1
#   * lon           (lon) float32 12.0 12.0 12.01 12.02 ... 12.07 12.08 12.09 12.1
# Data variables:
#     analysed_sst  (time, lat, lon) float32 ...
# Attributes: (12/55)
#     Conventions:                CF-1.4
#     title:                      Mediterranean SST Analysis, L4, 1km daily (SS...
#     summary:                    Daily gap-free maps (L4) at 1/100deg. x 1/100...
#     references:                 Buongiorno Nardelli, B., C. Tronconi, a. Pisa...
#     institution:                GOS
#     history:                    GOS-MYO processor V3: new version
#     ...                         ...
#     cdm_data_type:              grid
# ...

# %%
sst_ds2.info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:       (time: 731, lat: 13, lon: 13)
# Coordinates:
#   * time          (time) datetime64[ns] 2018-06-01 2018-06-02 ... 2020-05-31
#   * lat           (lat) float32 35.0 35.0 35.01 35.02 ... 35.07 35.08 35.09 35.1
#   * lon           (lon) float32 18.0 18.0 18.01 18.02 ... 18.07 18.08 18.09 18.1
# Data variables:
#     analysed_sst  (time, lat, lon) float32 ...
# Attributes: (12/55)
#     Conventions:                CF-1.4
#     title:                      Mediterranean SST Analysis, L4, 1km daily (SS...
#     summary:                    Daily gap-free maps (L4) at 1/100deg. x 1/100...
#     references:                 Buongiorno Nardelli, B., C. Tronconi, a. Pisa...
#     institution:                GOS
#     history:                    GOS-MYO processor V3: new version
#     ...                         ...
#     cdm_data_type:              grid
# ...

# %% [markdown]
# ## 4.4. Set the configuration

# %%
# Set the variable names (used later for accessing the data)
lon_name = "lon"
lat_name= "lat"
time_name = "time"
sst_name = "analysed_sst"

# %% [markdown]
# ## 4.5. Plot the time series

# %% [markdown]
# ### Choose the points of interest:

# %%
# Set the points of interest

point1 = {'x': 12.00, 'y': 40.00}
point2 = {'x': 18.00, 'y': 35.00}

# %% [markdown]
# ### Extract the dataset for the selected points:

# %%
# Extract the sub-dataset for the first defined point
ds_sel1 = sst_ds1.sel(lat=point1['y'], lon=point1['x'], method='nearest')
ds_sel1
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 731)
# Coordinates:
#   * time          (time) datetime64[ns] 2018-06-01 2018-06-02 ... 2020-05-31
#     lat           float32 40.0
#     lon           float32 12.0
# Data variables:
#     analysed_sst  (time) float32 ...
# Attributes: (12/55)
#     Conventions:                CF-1.4
#     title:                      Mediterranean SST Analysis, L4, 1km daily (SS...
#     summary:                    Daily gap-free maps (L4) at 1/100deg. x 1/100...
#     references:                 Buongiorno Nardelli, B., C. Tronconi, a. Pisa...
#     institution:                GOS
#     history:                    GOS-MYO processor V3: new version
#     ...                         ...
#     cdm_data_type:              grid
#     History:                    Translated to CF-1.0 Conventions by Netcdf-Ja...
#     geospatial_lat_min:         39.99583435058594
#     geospatial_lat_max:         40.09583282470703
# ...

# %%
# Extract the sub-dataset for the second defined point
ds_sel2 = sst_ds2.sel(lat=point2['y'], lon=point2['x'], method='nearest')
ds_sel2
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 731)
# Coordinates:
#   * time          (time) datetime64[ns] 2018-06-01 2018-06-02 ... 2020-05-31
#     lat           float32 35.0
#     lon           float32 18.0
# Data variables:
#     analysed_sst  (time) float32 ...
# Attributes: (12/55)
#     Conventions:                CF-1.4
#     title:                      Mediterranean SST Analysis, L4, 1km daily (SS...
#     summary:                    Daily gap-free maps (L4) at 1/100deg. x 1/100...
#     references:                 Buongiorno Nardelli, B., C. Tronconi, a. Pisa...
#     institution:                GOS
#     history:                    GOS-MYO processor V3: new version
#     ...                         ...
#     cdm_data_type:              grid
#     History:                    Translated to CF-1.0 Conventions by Netcdf-Ja...
#     geospatial_lat_min:         34.99583435058594
#     geospatial_lat_max:         35.09583282470703
# ...

# %% [markdown]
# ### Extract the SST values for the selected timeseries:

# %%
# Extract the SST values for the first point
sst_sel1 = ds_sel1[sst_name].round(2)
sst_sel1
# Out:
# <xarray.DataArray 'analysed_sst' (time: 731)>
# array([295.15, 295.45, 295.85, 296.68, 296.53, 295.71, 295.45, 296.44,
#        296.29, 295.94, 296.31, 296.99, 297.03, 296.6 , 296.5 , 296.58,
#        296.89, 296.58, 297.12, 297.86, 297.87, 298.24, 297.62, 297.54,
#        297.36, 297.47, 297.32, 297.05, 296.53, 297.01, 297.3 , 297.69,
#        296.88, 297.52, 298.49, 298.82, 298.52, 298.47, 298.4 , 298.54,
#        298.98, 299.39, 299.46, 299.17, 299.33, 300.05, 299.91, 299.16,
#        298.54, 299.82, 300.11, 299.25, 298.35, 299.23, 299.28, 299.3 ,
#        299.49, 300.32, 300.24, 300.07, 300.52, 300.87, 300.77, 301.34,
#        301.66, 301.35, 301.54, 301.7 , 301.91, 301.83, 302.23, 301.77,
#        301.94, 302.39, 301.98, 301.76, 301.38, 301.25, 301.28, 301.46,
#        301.17, 300.95, 300.54, 300.96, 300.77, 300.53, 300.36, 299.97,
#        299.73, 299.36, 299.49, 299.51, 300.06, 299.74, 299.65, 299.47,
#        299.41, 299.56, 299.52, 299.74, 299.64, 299.82, 299.28, 299.8 ,
# ...

# %%
# Extract the SST values for the second point
sst_sel2 = ds_sel2[sst_name].round(2)
sst_sel2
# Out:
# <xarray.DataArray 'analysed_sst' (time: 731)>
# array([296.25, 296.38, 296.83, 297.53, 297.24, 296.89, 296.73, 296.57,
#        296.65, 296.59, 296.33, 296.68, 297.68, 297.19, 296.76, 296.6 ,
#        296.77, 296.75, 297.04, 297.69, 297.67, 297.5 , 298.15, 298.12,
#        298.39, 297.75, 297.16, 297.26, 296.97, 296.98, 297.42, 298.23,
#        298.57, 297.93, 298.68, 298.07, 297.62, 298.36, 298.76, 299.11,
#        299.15, 299.55, 299.64, 299.9 , 299.28, 300.01, 300.55, 300.01,
#        299.93, 299.89, 299.98, 300.07, 299.86, 300.49, 299.97, 300.  ,
#        300.17, 300.46, 300.59, 300.57, 300.68, 300.87, 301.13, 300.72,
#        301.19, 301.52, 301.86, 301.19, 301.33, 301.41, 301.55, 301.2 ,
#        301.22, 301.42, 301.38, 301.53, 301.04, 301.3 , 301.32, 301.52,
#        301.28, 301.4 , 301.59, 301.26, 301.14, 300.92, 300.56, 300.23,
#        300.4 , 300.37, 300.3 , 300.14, 300.3 , 300.38, 300.31, 300.3 ,
#        300.09, 300.58, 299.73, 300.32, 300.7 , 300.55, 300.04, 301.09,
# ...

# %% [markdown]
# ### Convert the two datasets into a pandas DataFrame

# %%
# define two labels
fname1 = "SST (%s, %s)" % (point1["x"], point1["y"])
fname2 = "SST (%s, %s)" % (point2["x"], point2["y"])

# create dates np.array for the x axis
dates=[]
for i in range(len(sst_sel1.time.values)) : 
    dates.append(np.datetime64(sst_sel1.time.values[i]))
dates= np.array(dates)   

# create a dataframe with data of the first and second points
df = pd.DataFrame({"Dates": dates, 
                    fname1: sst_sel1,
                    fname2: sst_sel2})
# and let’s set the Dates as the DataFrame’s index.
df = df.set_index('Dates')

# %% [markdown]
# ### Have a look at the data

# %%
## print just a section of this dataframe
df[100:200:1]
# Out:
#             SST (12.0, 40.0)  SST (18.0, 35.0)
# Dates
# 2018-09-09        299.640015        300.700012
# 2018-09-10        299.820007        300.549988
# 2018-09-11        299.279999        300.040009
# 2018-09-12        299.799988        301.089996
# 2018-09-13        299.730011        300.470001
# ...                      ...               ...
# 2018-12-13        289.450012        292.140015
# 2018-12-14        289.489990        292.369995
# 2018-12-15        289.720001        292.299988
# 2018-12-16        289.700012        291.970001
# 2018-12-17        289.660004        291.489990
#
# [100 rows x 2 columns]

# %%
# print some summary statitics 
df.describe()
# Out:
#        SST (12.0, 40.0)  SST (18.0, 35.0)
# count        731.000000        731.000000
# mean         293.221222        294.252380
# std            4.932041          4.597592
# min          286.649994        287.869995
# 25%          288.429993        289.440002
# 50%          291.980011        293.829987
# 75%          298.429993        298.944992
# max          302.390015        302.049988

# %% [markdown]
# ### Compute monthly averages

# %%
# to compute monthly averages we will use the DataFrame’s resample() method
# this splits the DatetimeIndex into time bins and groups the data by time bin
# Resample to monthly frequency, aggregating with mean
df_mean = df.resample("M").mean()

# print some summary statitics 
df_mean.describe()
# Out:
#        SST (12.0, 40.0)  SST (18.0, 35.0)
# count         24.000000         24.000000
# mean         293.193695        294.227814
# std            4.956773          4.611084
# min          287.059998        288.341431
# 25%          288.519905        289.405243
# 50%          292.368896        294.169006
# 75%          297.399925        298.245010
# max          301.088715        301.106140

# %% [markdown]
# ### Save the data in csv file format

# %%
# save the dataframe to a csv file
fname_table = "sst_data.csv"
output_table =  os.path.join(out_path, fname_table)
df.to_csv(output_table)

# ...then verify if the file exists
if os.path.isfile(output_table):
    print(output_table)
# Out:
# ./out/10-01\sst_data.csv

# %% [markdown]
# ### Plot

# %%
# we will use the location in the panda data frame to define the x-range

# Start and end of the date range to plot
start, end = '2018', '2020'

# prepare the plot 
fig, ax = plt.subplots(figsize=(20,12))



# plot the first column of the pandas dataframe for the daility times series 
ax.plot(df.loc[start:end, fname1],
        linestyle=':', lw=1, 
        marker='o' ,color="tomato",label=fname1+'-Daily')

# add to the plot the second column of the pandas dataframe
ax.plot(df.loc[start:end, fname2],
        linestyle=':', lw=1, 
        marker='o',  color="royalblue",label=fname2+'-Daily')

 
# now plot also the  monthly averages
# add a # before the """ at the start and botton of this section to uncomment it
"""
ax.plot(df_mean.loc[start:end, fname1],
        linestyle='-', lw=3, color="darkred",label=fname1+'-Monthly')
ax.plot(df_mean.loc[start:end, fname2],
        linestyle='-', lw=3,color="darkblue",label=fname2+'-Monthly')
"""

# format the x axis ticks
years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
#plot.set_xlim(datemin, datemax)
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')

# format the y axis and ticks 
ax.set_ylabel('SST (K)')
# set the Y on LOG: COMMENT FOR LINEAR RANGE
#ax.set_yscale("log")
#ax.set_yticks([0.1,1,10])
#ax.set_yticklabels(["0.1","1","10"])

# set the grid
ax.grid(True)

# set the legend
ax.legend();

# set title
title = ds_sel1[sst_name].long_name + " in the Mediterranean Sea"
ax.set_title(title);

# output file
output_file = os.path.join(out_path,ds_sel1[sst_name].long_name.replace(' ','_')) + ".png"

# save the output file
plt.savefig(output_file)

# plot!
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### LET'S TRY: Change the plot!
#
# If you want, you can change the above plot.
#
# For example, you could:
# - plot the monthly means
# - change the start and end of the date range to plot a portion of the time series
#
#
# Go back to [Configure the variables for the plots](#Configure-the-variables-for-the-plots) and then re-execute the cell for generating the plot. Try!

# %% [markdown]
# ***

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>CONGRATULATIONS</b><br>
#
# ---
#
# #### And thank you for your attention! :) We hope you enjoyed this training on the Mediterranean Sea Surface Temperature data provided by Copernicus Marine Service, for free, thanks to the European Commission.
#
# #### Now let's try to download new data and variables and to access and visualize them... you can try to make new maps and plots... and don't forget to try to the other [Copernicus Marine products](http://marine.copernicus.eu/services-portfolio/access-to-products/?option=com_csw&task=results)
#
# This training course is over but we'd love to hear from you about how we could improve it (topics, tools, storytelling, format, speed etc).
#
# We do thank you in advance for your kind collaboration :)
